# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
songs = pd.read_csv('songs_final422.csv')

# %%
songs
# Out:
#                  Artist                                         Song Title  \
# 0            Bruno Mars                     ['Finesse', '(', 'Remix', ')']
# 1            Bruno Mars                ['When', 'I', 'Was', 'Your', 'Man']
# 2            Bruno Mars                  ['Versace', 'on', 'the', 'Floor']
# 3            Bruno Mars                                   ['24K', 'Magic']
# 4            Bruno Mars                             ['It', 'Will', 'Rain']
# ...                 ...                                                ...
# 10375                MØ                                  ['Final', 'Song']
# 10376        Kanye West               ['Devil', 'In', 'A', 'New', 'Dress']
# 10377  The Four Seasons  ['December', ',', '1963', '(', 'Oh', ',', 'Wha...
# 10378      Richard Marx                       ['Right', 'Here', 'Waiting']
# 10379      Mario Winans            ['I', 'Do', "n't", 'Wan', 'na', 'Know']
#
#                                  Stemmed With Stop Words  \
# 0      ['drop', 'top', 'porsch', 'porsch', 'rolli', '...
# 1      ['same', 'bed', 'but', 'it', 'feel', 'just', '...
# 2      ['let', "'s", 'take', 'our', 'time', 'tonight'...
# 3      ['tonight', 'i', 'just', 'wan', 'na', 'take', ...
# 4      ['if', 'you', 'ever', 'leav', 'me', 'babi', 'l...
# ...                                                  ...
# 10375  ['pleas', 'wo', "n't", 'you', 'wait', 'wo', "n...
# 10376  ['uh', 'uh', 'i', 'love', 'it', 'though', 'i',...
# 10377  ['oh', 'what', 'a', 'night', 'late', 'decemb',...
# 10378  ['ocean', 'apart', 'day', 'after', 'day', 'and...
# 10379  ['hold', 'up', 'let', 'me', 'answer', 'my', 'p...
#
#                                    Stemmed No Stop Words  Row_Index Genre
# 0      ['drop', 'top', 'porsch', 'porsch', 'rolli', '...          0   R&B
# 1      ['bed', 'feel', 'littl', 'bit', 'bigger', 'son...          1   Pop
# 2      ['let', "'s", 'take', 'time', 'tonight', 'girl...          2   R&B
# 3      ['tonight', 'wan', 'na', 'take', 'higher', 'th...          3   R&B
# 4      ['ever', 'leav', 'babi', 'leav', 'morphin', 'd...          4   Pop
# ...                                                  ...        ...   ...
# 10375  ['pleas', 'wo', "n't", 'wait', 'wo', "n't", 's...      10441   Pop
# 10376  ['uh', 'uh', 'love', 'though', 'love', 'though...      10442   Rap
# 10377  ['oh', 'night', 'late', 'decemb', 'back', "'63...      10443   Pop
# 10378  ['ocean', 'apart', 'day', 'day', 'slowli', 'go...      10444   Pop
# 10379  ['hold', 'let', 'answer', 'phone', 'bitch', 'c...      10445   Pop
#
# [10380 rows x 6 columns]

# %%
songs['Genre'].value_counts()
# Out:
# Genre
# Pop        3757
# Rock       2188
# Rap        2044
# EDM        1125
# R&B         854
# Country     412
# Name: count, dtype: int64

# %%
X = songs['Stemmed No Stop Words']

# %%
y = songs['Genre']

# %%
le = LabelEncoder()
y_le = le.fit_transform(y)

# %%
np.unique(y_le)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
y_le
# Out:
# array([3, 2, 3, ..., 2, 2, 2])

# %%
print("Classes:", le.classes_)
# Out:
# Classes: ['Country' 'EDM' 'Pop' 'R&B' 'Rap' 'Rock']

# %%
#we need to vectorize X since SVM can not interpret raw text
bagofwords = CountVectorizer()
X = bagofwords.fit_transform(X)

# %%
X
# Out:
# <10380x35737 sparse matrix of type '<class 'numpy.int64'>'
# 	with 931512 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_le, test_size=0.20, random_state=51)

# %%
#a base model without adjusting class_weights to account for class imbalance
svcmodel1 = SVC()

# %%
#a base model without adjusting class_weights to account for class imbalance
svcmodel1 = SVC()
# Out:
# SVC()

# %%
svc_predictions = svcmodel1.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
svc1_report = classification_report(y_test, svc1_predictions, target_names=["Country", "EDM", "Pop", "R&B", "Rap", "Rock"])
print(svc1_report)
# Out:
#               precision    recall  f1-score   support
#
#      Country       1.00      0.05      0.09        85
#          EDM       0.38      0.01      0.02       233
#          Pop       0.47      0.84      0.61       742
#          R&B       0.82      0.05      0.10       169
#          Rap       0.80      0.68      0.74       412
#         Rock       0.48      0.42      0.45       435
#
#     accuracy                           0.53      2076
#    macro avg       0.66      0.34      0.33      2076
# weighted avg       0.58      0.53      0.47      2076

# %%
#now we are running a model where we account for the class imbalance

svcmodel2 = SVC(class_weight = 'balanced')

# %%
svcmodel2.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced')

# %%
svc2_predictions = svcmodel2.predict(X_test)

# %%
svc2_report = classification_report(y_test, svc2_predictions, target_names=["Country", "EDM", "Pop", "R&B", "Rap", "Rock"])
print(svc2_report)
# Out:
#               precision    recall  f1-score   support
#
#      Country       0.37      0.45      0.41        85
#          EDM       0.32      0.33      0.32       233
#          Pop       0.58      0.42      0.49       742
#          R&B       0.26      0.28      0.27       169
#          Rap       0.77      0.71      0.74       412
#         Rock       0.43      0.63      0.51       435
#
#     accuracy                           0.50      2076
#    macro avg       0.46      0.47      0.46      2076
# weighted avg       0.52      0.50      0.50      2076

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# create a confusion matrix for the balanced model
svc2_cm = confusion_matrix(y_test, svc2_predictions)

# %%
# plot the confusion matrix
svc2_cm_plot = ConfusionMatrixDisplay(confusion_matrix=svc2_cm, display_labels=["Country", "EDM", "Pop", "R&B", "Rap", "Rock"])
svc2_cm_plot.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix with Balanced SVM, Bag of Words")
plt.show()

# %%
#now we are going to use word2vec to generate dense vectors

# %%
pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\programdata\anaconda3\lib\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.13.1)
# Collecting scipy
#   Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 814.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\programdata\anaconda3\lib\site-packages (from scipy) (1.26.4)
# Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl (40.9 MB)
#    ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/40.9 MB 14.9 MB/s eta 0:00:03
#    - -------------------------------------- 1.4/40.9 MB 18.2 MB/s eta 0:00:03
#    -- ------------------------------------- 2.6/40.9 MB 20.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.5/40.9 MB 26.0 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/40.9 MB 31.1 MB/s eta 0:00:02
#    -------- ------------------------------- 8.6/40.9 MB 36.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 11.5/40.9 MB 50.4 MB/s eta 0:00:01
#    ------------- -------------------------- 14.1/40.9 MB 59.5 MB/s eta 0:00:01
#    ------------------ --------------------- 19.3/40.9 MB 81.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 23.4/40.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.8/40.9 MB 108.8 MB/s eta 0:00:01
#    ------------------------------- -------- 32.0/40.9 MB 93.9 MB/s eta 0:00:01
#    ------------------------------------ --- 37.7/40.9 MB 93.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/40.9 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 40.9/40.9 MB 65.5 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.2

# %%
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 from gensim.models import Word2Vec
#
# File C:\ProgramData\anaconda3\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File C:\ProgramData\anaconda3\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File C:\ProgramData\anaconda3\Lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\gensim\matutils.py:20
#      18 import scipy.sparse
#      19 from scipy.stats import entropy
# ---> 20 from scipy.linalg import get_blas_funcs, triu
#      21 from scipy.linalg.lapack import get_lapack_funcs
#      22 from scipy.special import psi  # gamma function utils
#
# ImportError: cannot import name 'triu' from 'scipy.linalg' (C:\ProgramData\anaconda3\Lib\site-packages\scipy\linalg\__init__.py)
