# %%
from sklearn.naive_bayes import MultinomialNB
import pandas as pd 
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd 
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
#let's tell our second model what the prior probabilities are
classcounts = np.bincount(y_train)
classpriors = classcounts / len(y_train)

# %%
songs = pd.read_csv('songs_final422.csv')

# %%
X = songs['Stemmed No Stop Words']

# %%
y = songs['Genre']

# %%
le = LabelEncoder()
y_le = le.fit_transform(y)

# %%
print("Classes:", le.classes_)
# Out:
# Classes: ['Country' 'EDM' 'Pop' 'R&B' 'Rap' 'Rock']

# %%
#we need to vectorize X since SVM can not interpret raw text
bagofwords = CountVectorizer()
X = bagofwords.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_le, test_size=0.20, random_state=51)

# %%
#a base model without adjusting class_weights to account for class imbalance
nbmodel1 = MultinomialNB()

# %%
nbmodel1.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nb1_predictions = nbmodel1.predict(X_test)

# %%
nb1_report = classification_report(y_test, nb1_predictions, target_names=["Country", "EDM", "Pop", "R&B", "Rap", "Rock"])
print(nb1_report)
# Out:
#               precision    recall  f1-score   support
#
#      Country       0.26      0.12      0.16        85
#          EDM       0.46      0.13      0.20       233
#          Pop       0.51      0.62      0.56       742
#          R&B       0.28      0.11      0.16       169
#          Rap       0.75      0.75      0.75       412
#         Rock       0.46      0.61      0.52       435
#
#     accuracy                           0.53      2076
#    macro avg       0.45      0.39      0.39      2076
# weighted avg       0.51      0.53      0.50      2076

# %%
# create a confusion matrix for the balanced model
nb1_cm = confusion_matrix(y_test, nb1_predictions)

# %%
# plot the confusion matrix
nb1_cm_plot = ConfusionMatrixDisplay(confusion_matrix=nb1_cm, display_labels=["Country", "EDM", "Pop", "R&B", "Rap", "Rock"])
nb1_cm_plot.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix with Naive Bayes, Bag of Words")
plt.show()

# %%
from gensim.models import Word2Vec
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
word2vec_model = Word2Vec(X, vector_size=100, window=5, min_count=1, workers=4)
wvX = word2vec_model.wv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 word2vec_model = Word2Vec(X, vector_size=100, window=5, min_count=1, workers=4)
#       2 wvX = word2vec_model.wv
#
# File ~\AppData\Roaming\Python\Python312\site-packages\gensim\models\word2vec.py:429, in Word2Vec.__init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     427 if corpus_iterable is not None or corpus_file is not None:
#     428     self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
# --> 429     self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
#     430     self.train(
#     431         corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     432         total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
#     433         end_alpha=self.min_alpha, compute_loss=self.compute_loss, callbacks=callbacks)
#     434 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\gensim\models\word2vec.py:491, in Word2Vec.build_vocab(self, corpus_iterable, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     453 """Build vocabulary from a sequence of sentences (can be a once-only generator stream).
#     454
#     455 Parameters
#    (...)
#     488
#     489 """
#     490 self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=1)
# --> 491 total_words, corpus_count = self.scan_vocab(
#     492     corpus_iterable=corpus_iterable, corpus_file=corpus_file, progress_per=progress_per, trim_rule=trim_rule)
#     493 self.corpus_count = corpus_count
#     494 self.corpus_total_words = total_words
#
# File ~\AppData\Roaming\Python\Python312\site-packages\gensim\models\word2vec.py:586, in Word2Vec.scan_vocab(self, corpus_iterable, corpus_file, progress_per, workers, trim_rule)
#     583 if corpus_file:
#     584     corpus_iterable = LineSentence(corpus_file)
# --> 586 total_words, corpus_count = self._scan_vocab(corpus_iterable, progress_per, trim_rule)
#     588 logger.info(
#     589     "collected %i word types from a corpus of %i raw words and %i sentences",
#     590     len(self.raw_vocab), total_words, corpus_count
#     591 )
#     593 return total_words, corpus_count
#
# File ~\AppData\Roaming\Python\Python312\site-packages\gensim\models\word2vec.py:570, in Word2Vec._scan_vocab(self, sentences, progress_per, trim_rule)
#     565     logger.info(
#     566         "PROGRESS: at sentence #%i, processed %i words, keeping %i word types",
#     567         sentence_no, total_words, len(vocab),
#     568     )
#     569 for word in sentence:
# --> 570     vocab[word] += 1
#     571 total_words += len(sentence)
#     573 if self.max_vocab_size and len(vocab) > self.max_vocab_size:
#
# TypeError: unhashable type: 'csr_matrix'
